# %% [markdown]
# ## Narzędzie graficzne
# Do wizualizacji programu użyto zmodyfikowanego narzędzia graficznego mgr. inż. Krzysztofa Podsiadło.
# Dodano m.in. kilka przycików oraz możliwość dodawania do scen obiektów z matplotlib.patches

# %%
# %matplotlib notebook
from AuxFiles.tool import *    #plik, w którym znajduje się narzędzie graficzne

# %% [markdown]
# # KD-drzewa

# %% [markdown]
# # Rozwiązanie
# Sprawdzenie wyniku, dla danego przykładu (bez wizualizacji)

# %%
from AuxFiles.testDataGenerator import TestDataGen

from kdTree.kdtreeAuxClasses import Range
from kdTree.kdtree import KDTree


points = [(3, 1), (1, 2), (6, 0), (7, 5), (4, 3)]
testTree = KDTree(points)

searchingRange = Range(2, 5, 0, 4)
print(testTree.search(searchingRange))
# Out:
# [(3, 1), (4, 3)]

# %% [markdown]
# ## Wizualizacja konstrukacji kd tree 1
# Dla prostego przykładu

# %%
from kdTree.kdtreevis import KDTreeVis


points = [(3, 1), (1, 2), (6, 0), (7, 5), (4, 3)] 
testKDTreeVis = KDTreeVis(points)

plot = testKDTreeVis.getInitPlot()
plot.draw()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Przeszukiwanie

# %%
searchingRange = Range(2, 5, 0, 4)

testKDTreeVis.search(searchingRange)
plot = testKDTreeVis.getSearchPlot()
plot.draw()
testKDTreeVis.clearVis()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Wizualizacja konstrukcji kd tree 2
# Dla wygnerowanego zbioru punktów

# %%
from kdTree.kdtreevis import KDTreeVis
from AuxFiles.testDataGenerator import TestDataGen


# Konstrukcja generatora
dataGenerator = TestDataGen()
# Genrowanie przykładowych zestawów danych.
# Każda metoda generująca zwraca listę punktów,
# więc ich winiki można dowonie łączyć

# P = dataGenerator.inRect(n=100, x1=0, x2=10, y1=0, y2=10)
# P = dataGenerator.cirque(n=100, x=0, y=0, R=10)#
# P = dataGenerator.sinus(n=250, x1=0, x2=10, y1=0, y2=10)
# P = dataGenerator.rectDiagonals(n1=100, n2=100, x1=0, x2=10, y1=0, y2=10)#
P = dataGenerator.archimedeanSpiral(n=450, x=0, y=0, maxR=10, lapses=5, direct=1)
# P = dataGenerator.rectDiagonals() + dataGenerator.rectDiagonals()
# P = dataGenerator.archimedeanSpiral() + dataGenerator.archimedeanSpiral(direct=-1)#

testKDTreeVis = KDTreeVis(P)
plot = testKDTreeVis.getInitPlot()
plot.draw()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Przeszukiwanie

# %%
#searchingRange = Range(2, 6.5, 3.5, 5.5)
searchingRange = Range(-5, 5, -3.5, 3.5)

testKDTreeVis.search(searchingRange)
plot = testKDTreeVis.getSearchPlot()
plot.draw()
testKDTreeVis.clearVis()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Quad Tree

# %% [markdown]
# # Rozwiązanie
# Sprawdzenie wyniku, dla danego przykładu (bez wizualizacji)

# %%
# %matplotlib notebook
from quadTree.QuadTree import *

P = [(3, 1), (1, 2), (6, 0), (7, 5), (4, 3)]
testTree = QuadTree(P=P)

searchingRange = Rect(2, 5, 0, 4)
print(testTree.searchInRange(searchingRange))
# Out:
# [(3, 1), (4, 3)]

# %% [markdown]
# ## Wizualizacja konstrukcji Quad Tree 1
# Dla prostego przykładu

# %%
from quadTree.QuadTreeVis import *

P = [(3, 1), (1, 2), (6, 0), (7, 5), (4, 3), (2, 5), (5, 5)] 
testTree = QuadTree(P=P, eachNodeContainsPoints=True)
testTreeVis = QuadTreeVis(testTree)

plot = testTreeVis.getConstructionVis()
plot.draw()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Przeszukiwanie

# %%
queryRect = Rect(2, 5, 0, 4)
plot = testTreeVis.getRangeQueryVis(queryRect)
plot.draw()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Wizualizacja konstruckji Quad Tree 2
# Dla wygnerowanego zbioru punktów

# %%
from quadTree.QuadTreeVis import *
from AuxFiles.testDataGenerator import TestDataGen

# Konstrukcja generatora
dataGenerator = TestDataGen()
# Genrowanie przykładowych zestawów danych.
# Każda metoda generująca zwraca listę punktów,
# więc ich winiki można dowonie łączyć

# P = dataGenerator.inRect(n=100, x1=0, x2=10, y1=0, y2=10)
# P = dataGenerator.cirque(n=100, x=0, y=0, R=10)#
# P = dataGenerator.sinus(n=250, x1=0, x2=10, y1=0, y2=10)
P = dataGenerator.rectDiagonals(n1=100, n2=100, x1=0, x2=10, y1=0, y2=10) + dataGenerator.rectDiagonals(n1=100, n2=100, x1=5, x2=10, y1=0, y2=10)
# P = dataGenerator.archimedeanSpiral(n=450, x=0, y=0, maxR=10, lapses=5, direct=1)
# P = dataGenerator.rectDiagonals() + dataGenerator.rectDiagonals()
# P = dataGenerator.archimedeanSpiral() + dataGenerator.archimedeanSpiral(direct=-1)#

eachNodeContainsPoints = True
allowDuplicate = False
qt = QuadTree(P=P, eachNodeContainsPoints=eachNodeContainsPoints, allowDuplicate=allowDuplicate)
print(qt.getDepth())
qtVis = QuadTreeVis(qt)

plotInit = qtVis.getConstructionVis(withFinalSetOfLines=False)
plotInit.draw()
# Out:
# 16
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Przeszukiwanie

# %%
queryRect = Rect(2.5, 7, 3.3, 6.1)

plotSearch = qtVis.getRangeQueryVis(queryRect, instantReportingAtInternalNode = True)
plotSearch.draw()
# Out:
# <img src="data:image/png;base64,..." width="640">
